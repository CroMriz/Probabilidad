# %%
from statistics import *

# %%
##Histogramas de 2 grupos

# %%
# Libreria para generar numeros aleatorios
import random

# %%
fabrica1 = []
for i in range(100):
    numero_aleatorio = round( random.uniform(50, 100), 2 )
    fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [71.32, 70.38, 75.37, 78.4, 75.08, 53.72, 77.17, 56.75, 70.45, 53.17, 60.12, 54.0, 62.27, 70.84, 94.72, 55.13, 88.11, 91.19, 66.72, 71.35, 96.66, 52.33, 99.12, 94.53, 67.2, 76.45, 58.08, 60.14, 53.9, 64.85, 95.18, 95.43, 81.1, 79.25, 90.0, 53.61, 70.73, 94.51, 54.05, 62.01, 91.41, 64.37, 69.25, 77.35, 86.99, 89.86, 59.6, 82.79, 60.9, 87.93, 58.81, 71.72, 70.28, 74.43, 53.53, 82.85, 61.47, 86.31, 90.52, 51.64, 90.76, 70.74, 50.66, 90.91, 59.27, 67.5, 94.77, 69.85, 81.42, 72.7, 73.21, 85.53, 72.07, 84.61, 60.83, 54.87, 55.79, 60.67, 93.66, 84.71, 79.96, 98.7, 56.87, 73.55, 98.89, 79.51, 78.01, 83.29, 70.89, 66.71, 60.42, 95.46, 60.46, 96.6, 94.12, 66.91, 58.02, 69.16, 86.01, 66.75]

# %%
fabrica2 = []
for i in range(100):
    numero_aleatorio2 = round( random.uniform(50, 100), 2 )
    fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [67.74, 94.34, 99.43, 83.06, 65.83, 65.75, 79.17, 66.58, 83.46, 85.79, 80.91, 53.25, 85.36, 61.25, 59.59, 51.2, 98.36, 82.82, 98.95, 82.48, 92.96, 78.6, 85.78, 88.48, 78.65, 97.15, 82.75, 85.1, 85.97, 78.66, 69.39, 86.13, 90.29, 77.82, 51.67, 89.69, 99.74, 99.72, 52.4, 78.04, 66.37, 91.19, 87.43, 68.14, 51.45, 82.6, 60.47, 77.93, 52.15, 87.31, 71.48, 55.42, 54.43, 73.03, 73.71, 56.66, 72.61, 52.22, 88.8, 72.48, 88.6, 55.54, 63.97, 92.81, 50.2, 64.12, 95.8, 51.37, 82.14, 84.22, 52.89, 58.83, 78.19, 80.47, 84.82, 93.7, 83.05, 65.26, 98.63, 82.19, 70.97, 54.79, 57.23, 64.91, 99.06, 95.78, 52.51, 84.61, 93.88, 74.1, 68.0, 85.64, 94.67, 96.01, 53.39, 57.4, 90.58, 65.8, 51.13, 98.82]

# %%
# Libreia de python para graficar valores
import matplotlib.pyplot as plt

# %%
plt.hist(fabrica1)
plt.title("Produccion diaria de la Fabrica 1")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la Fabrica 1')

# %%
plt.hist(fabrica2)
plt.title("Produccion diaria de la Fabrica 2")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la Fabrica 2')

# %%
media=mean(fabrica1)
mediana=median(fabrica1)
moda=mode(fabrica1)

print("Valores de la fabrica 1")
print("La media es =", media)
print("la mediana es =", mediana)
print("la moda es =", moda)
# Out:
# Valores de la fabrica 1
# La media es = 73.8222
# la mediana es = 71.535
# la moda es = 71.32

# %%
media=mean(fabrica2)
mediana=median(fabrica2)
moda=mode(fabrica2)

print("Valores de la fabrica 2")
print("La media es =", media)
print("la mediana es =", mediana)
print("la moda es =", moda)
# Out:
# Valores de la fabrica 2
# La media es = 76.0627
# la mediana es = 78.655
# la moda es = 67.74

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
# Valor minimo, maximo, rango

media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

# %%
plt.hist(fabrica1, bins=20, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel('valor')
plt.ylabel('Frecuencia')
plt.title("produccion diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

plt.hist(fabrica2, bins=20, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel('valor')
plt.ylabel('Frecuencia')
plt.title("Produccion diaria de la fabrica 2")
plt.legend()
plt.show()

# %% [markdown]
# ##Maximo, minimo y rango

# %%
maximo = max(fabrica1)
minimo = min(fabrica1)
rango = maximo - minimo
media = mean(fabrica1)
mediana = median(fabrica1)
moda = mode(fabrica1)

print( "Estadistica descriptiva de la fabrica 1 \n", "media =", media, "\n Mediana =", mediana, "\n Moda =", moda, "\n Maximo =", maximo, "\n Minimo =", minimo, "\n Rango =", rango)
# Out:
# Estadistica descriptiva de la fabrica 1
#  media = 73.8222
#  Mediana = 71.535
#  Moda = 71.32
#  Maximo = 99.12
#  Minimo = 50.66
#  Rango = 48.46000000000001

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo - minimo
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print( "Estadistica descriptiva de la fabrica 2 \n", "media =", media2, "\n Mediana =", mediana2, "\n Moda =", moda2, "\n Maximo =", maximo2, "\n Minimo =", minimo2, "\n Rango =", rango2)
# Out:
# Estadistica descriptiva de la fabrica 2
#  media = 76.0627
#  Mediana = 78.655
#  Moda = 67.74
#  Maximo = 99.74
#  Minimo = 50.2
#  Rango = 48.46000000000001

# %% [markdown]
# ##Dispersion de los datos

# %%
desviacion_estandar_fabrica1 = stdev(fabrica1)
print("La desviacion estandar de la fabrica 1 es =", desviacion_estandar_fabrica1)
# Out:
# La desviacion estandar de la fabrica 1 es = 14.205007267676686

# %%
desviacion_estandar_fabrica2 = stdev(fabrica2)
print("La desviacion estandar de la fabrica 2 es =", desviacion_estandar_fabrica2)
# Out:
# La desviacion estandar de la fabrica 2 es = 15.385700816214404

# %%
plt.figure(figsize = (10,8) )
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'Media={media1:.2f}')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana1:.2f}')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda1:.2f}')

plt.axvline(media - desviacion_estandar_fabrica1, color='black', linestyle='dashed', linewidth=2, label=f'Desv. Estandar ={desviacion_estandar_fabrica1:.2f}')
plt.axvline(media + desviacion_estandar_fabrica1, color='black', linestyle='dashed', linewidth=2)

plt.xlabel('valor')
plt.ylabel('Frecuencia')
plt.title("produccion diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.figure(figsize = (10,8) )
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f'Media={media2:.2f}')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana2:.2f}')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda2:.2f}')

plt.axvline(media2 - desviacion_estandar_fabrica2, color='black', linestyle='dashed', linewidth=2, label=f'Desv. Estandar ={desviacion_estandar_fabrica2:.2f}')
plt.axvline(media2 + desviacion_estandar_fabrica2, color='black', linestyle='dashed', linewidth=2)

plt.xlabel('valor')
plt.ylabel('Frecuencia')
plt.title("produccion diaria de la fabrica 1")
plt.legend()
plt.show()
