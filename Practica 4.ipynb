# %%
from statistics import *

# %%
##Histogramas de 2 grupos

# %%
# Libreria para generar numeros aleatorios
import random

# %%
fabrica1 = []
for i in range(100):
    numero_aleatorio = round( random.uniform(50, 100), 2 )
    fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [93.12, 52.91, 61.4, 61.09, 83.66, 91.72, 63.13, 89.72, 80.65, 73.23, 91.28, 83.42, 85.81, 81.68, 93.89, 60.94, 68.5, 98.82, 88.25, 89.03, 88.51, 73.52, 56.56, 74.71, 97.01, 69.07, 78.97, 66.66, 80.09, 69.46, 97.02, 53.88, 88.77, 78.96, 50.42, 93.73, 80.68, 55.53, 62.52, 61.62, 96.44, 60.72, 92.6, 53.52, 50.81, 50.15, 71.98, 58.22, 67.56, 73.21, 88.64, 58.82, 78.35, 50.75, 69.66, 68.72, 53.78, 53.48, 88.22, 90.05, 85.57, 68.61, 83.2, 65.05, 86.04, 73.7, 82.81, 99.98, 83.16, 79.99, 65.65, 76.21, 54.44, 52.39, 85.45, 66.88, 66.69, 98.61, 62.6, 77.92, 89.62, 83.84, 92.66, 67.76, 85.74, 74.0, 77.19, 60.68, 76.46, 90.4, 78.38, 60.07, 63.26, 95.12, 66.18, 87.66, 74.91, 80.37, 82.88, 59.29]

# %%
fabrica2 = []
for i in range(100):
    numero_aleatorio2 = round( random.uniform(50, 100), 2 )
    fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [85.91, 79.55, 68.57, 68.41, 52.45, 97.31, 65.48, 80.53, 84.24, 69.19, 69.39, 88.21, 99.29, 97.16, 91.9, 70.89, 94.71, 82.81, 72.81, 53.49, 60.58, 63.78, 82.25, 52.97, 62.3, 97.18, 75.94, 68.26, 50.54, 67.14, 50.85, 64.63, 64.36, 98.77, 75.18, 95.67, 50.96, 94.04, 66.55, 98.52, 87.27, 58.22, 55.54, 74.27, 57.84, 53.46, 81.64, 85.91, 57.6, 74.79, 77.04, 74.67, 67.54, 99.72, 86.95, 53.69, 72.95, 52.74, 96.65, 59.37, 71.21, 56.78, 85.33, 81.65, 66.24, 83.17, 98.09, 73.6, 96.16, 93.64, 79.19, 60.52, 75.23, 83.74, 79.72, 52.05, 75.72, 71.53, 71.21, 83.08, 57.32, 77.1, 54.77, 79.98, 73.53, 71.42, 96.73, 53.61, 71.63, 53.79, 76.07, 62.0, 68.27, 82.72, 77.96, 77.81, 73.95, 55.61, 52.53, 99.76]

# %%
# Libreia de python para graficar valores
import matplotlib.pyplot as plt

# %%
plt.hist(fabrica1)
plt.title("Produccion diaria de la Fabrica 1")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la Fabrica 1')

# %%
plt.hist(fabrica2)
plt.title("Produccion diaria de la Fabrica 2")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la Fabrica 2')

# %%
media=mean(fabrica1)
mediana=median(fabrica1)
moda=mode(fabrica1)

print("Valores de la fabrica 1")
print("La media es =", media)
print("la mediana es =", mediana)
print("la moda es =", moda)
# Out:
# Valores de la fabrica 1
# La media es = 75.0704
# la mediana es = 76.335
# la moda es = 93.12

# %%
media=mean(fabrica2)
mediana=median(fabrica2)
moda=mode(fabrica2)

print("Valores de la fabrica 2")
print("La media es =", media)
print("la mediana es =", mediana)
print("la moda es =", moda)
# Out:
# Valores de la fabrica 2
# La media es = 73.9505
# la mediana es = 73.775
# la moda es = 85.91

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
# Valor minimo, maximo, rango

media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

# %%
plt.hist(fabrica1, bins=20, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel('valor')
plt.ylabel('Frecuencia')
plt.title("produccion diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

plt.hist(fabrica2, bins=20, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel('valor')
plt.ylabel('Frecuencia')
plt.title("Produccion diaria de la fabrica 2")
plt.legend()
plt.show()

# %% [markdown]
# ##Maximo, minimo y rango

# %%
maximo = max(fabrica1)
minimo = min(fabrica1)
rango = maximo - minimo
media = mean(fabrica1)
mediana = median(fabrica1)
moda = mode(fabrica1)

print( "Estadistica descriptiva de la fabrica 1 \n", "media =", media, "\n Mediana =", mediana, "\n Moda =", moda, "\n Maximo =", maximo, "\n Minimo =", minimo, "\n Rango =", rango)
# Out:
# Estadistica descriptiva de la fabrica 1
#  media = 75.0704
#  Mediana = 76.335
#  Moda = 93.12
#  Maximo = 99.98
#  Minimo = 50.15
#  Rango = 49.830000000000005

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo - minimo
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print( "Estadistica descriptiva de la fabrica 2 \n", "media =", media2, "\n Mediana =", mediana2, "\n Moda =", moda2, "\n Maximo =", maximo2, "\n Minimo =", minimo2, "\n Rango =", rango2)
# Out:
# Estadistica descriptiva de la fabrica 2
#  media = 73.9505
#  Mediana = 73.775
#  Moda = 85.91
#  Maximo = 99.76
#  Minimo = 50.54
#  Rango = 49.830000000000005

# %% [markdown]
# ##Dispersion de los datos

# %%
desviacion_estandar_fabrica1 = stdev(fabrica1)
print("La desviacion estandar de la fabrica 1 es =", desviacion_estandar_fabrica1)
# Out:
# La desviacion estandar de la fabrica 1 es = 13.924602014151976

# %%
desviacion_estandar_fabrica2 = stdev(fabrica2)
print("La desviacion estandar de la fabrica 2 es =", desviacion_estandar_fabrica2)
# Out:
# La desviacion estandar de la fabrica 2 es = 14.507413526270705

# %%
plt.figure(figsize = (10,8) )
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'Media={media1:.2f}')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana1:.2f}')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda1:.2f}')

plt.axvline(media - desviacion_estandar_fabrica1, color='black', linestyle='dashed', linewidth=2, label=f'Desv. Estandar ={desviacion_estandar_fabrica1:.2f}')
plt.axvline(media + desviacion_estandar_fabrica1, color='black', linestyle='dashed', linewidth=2)

plt.xlabel('valor')
plt.ylabel('Frecuencia')
plt.title("produccion diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.figure(figsize = (10,8) )
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f'Media={media2:.2f}')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana2:.2f}')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda2:.2f}')

plt.axvline(media2 - desviacion_estandar_fabrica2, color='black', linestyle='dashed', linewidth=2, label=f'Desv. Estandar ={desviacion_estandar_fabrica2:.2f}')
plt.axvline(media2 + desviacion_estandar_fabrica2, color='black', linestyle='dashed', linewidth=2)

plt.xlabel('valor')
plt.ylabel('Frecuencia')
plt.title("produccion diaria de la fabrica 1")
plt.legend()
plt.show()

# %% [markdown]
# ##Tablas de frecuencias

# %%
edades = []

for i in range (100):
    numero_aleatorio = random.randint(18, 70)
    edades.append(numero_aleatorio)
print (edades)
# Out:
# [38, 24, 22, 48, 59, 24, 63, 31, 36, 53, 35, 33, 45, 22, 28, 33, 58, 22, 36, 45, 40, 32, 41, 58, 70, 20, 37, 64, 61, 49, 33, 55, 65, 49, 63, 43, 31, 22, 18, 57, 56, 65, 19, 51, 37, 34, 32, 37, 26, 67, 38, 29, 60, 62, 38, 18, 41, 29, 55, 67, 30, 23, 51, 39, 25, 68, 19, 63, 63, 61, 52, 68, 28, 52, 35, 66, 69, 22, 36, 23, 22, 67, 41, 21, 43, 21, 37, 42, 43, 62, 25, 70, 35, 65, 48, 58, 50, 53, 31, 58]

# %%
import pandas as pd

# %%
df_edades = pd.DataFrame (edades, columns=["Edad"])
df_edades
# Out:
#     Edad
# 0     38
# 1     24
# 2     22
# 3     48
# 4     59
# ..   ...
# 95    58
# 96    50
# 97    53
# 98    31
# 99    58
#
# [100 rows x 1 columns]

# %%
# Valcular la tabla de distribucion de frecuencias
tabla_frecuencias = df_edades ["Edad"].value_counts().reset_index()
tabla_frecuencias.columns = ["Edad", "Frecuencia"]
tabla_frecuencias = tabla_frecuencias.sort_values(by = "Edad")
tabla_frecuencias
# Out:
#     Edad  Frecuencia
# 13    18           2
# 24    19           2
# 39    20           1
# 14    21           2
# 0     22           6
# 18    23           2
# 30    24           2
# 17    25           2
# 43    26           1
# 25    28           2
# 20    29           2
# 40    30           1
# 12    31           3
# 31    32           2
# 5     33           3
# 44    34           1
# 10    35           3
# 11    36           3
# 2     37           4
# 4     38           3
# 34    39           1
# 38    40           1
# 8     41           3
# 35    42           1
# 7     43           3
# 23    45           2
# 21    48           2
# 27    49           2
# 47    50           1
# 22    51           2
# 15    52           2
# 29    53           2
# 26    55           2
# 45    56           1
# 46    57           1
# 3     58           4
# 33    59           1
# 41    60           1
# 28    61           2
# 19    62           2
# 1     63           4
# 42    64           1
# 9     65           3
# 37    66           1
# 6     67           3
# 16    68           2
# 36    69           1
# 32    70           2

# %%
tabla_frecuencias ["Frec. Relativa"] = tabla_frecuencias ["Frecuencia"] / 100

# %%
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativa
# 13    18           2            0.02
# 24    19           2            0.02
# 39    20           1            0.01
# 14    21           2            0.02
# 0     22           6            0.06
# 18    23           2            0.02
# 30    24           2            0.02
# 17    25           2            0.02
# 43    26           1            0.01
# 25    28           2            0.02
# 20    29           2            0.02
# 40    30           1            0.01
# 12    31           3            0.03
# 31    32           2            0.02
# 5     33           3            0.03
# 44    34           1            0.01
# 10    35           3            0.03
# 11    36           3            0.03
# 2     37           4            0.04
# 4     38           3            0.03
# 34    39           1            0.01
# 38    40           1            0.01
# 8     41           3            0.03
# 35    42           1            0.01
# 7     43           3            0.03
# 23    45           2            0.02
# 21    48           2            0.02
# 27    49           2            0.02
# 47    50           1            0.01
# 22    51           2            0.02
# 15    52           2            0.02
# 29    53           2            0.02
# 26    55           2            0.02
# 45    56           1            0.01
# 46    57           1            0.01
# 3     58           4            0.04
# 33    59           1            0.01
# 41    60           1            0.01
# 28    61           2            0.02
# 19    62           2            0.02
# 1     63           4            0.04
# 42    64           1            0.01
# 9     65           3            0.03
# 37    66           1            0.01
# 6     67           3            0.03
# 16    68           2            0.02
# 36    69           1            0.01
# 32    70           2            0.02

# %%
# calcular la frecuencia porcentual
tabla_frecuencias["Frec. porcentual"] = tabla_frecuencias["Frecuencia"] /100 *100

# %%
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativa  Frec. porcentual
# 13    18           2            0.02               2.0
# 24    19           2            0.02               2.0
# 39    20           1            0.01               1.0
# 14    21           2            0.02               2.0
# 0     22           6            0.06               6.0
# 18    23           2            0.02               2.0
# 30    24           2            0.02               2.0
# 17    25           2            0.02               2.0
# 43    26           1            0.01               1.0
# 25    28           2            0.02               2.0
# 20    29           2            0.02               2.0
# 40    30           1            0.01               1.0
# 12    31           3            0.03               3.0
# 31    32           2            0.02               2.0
# 5     33           3            0.03               3.0
# 44    34           1            0.01               1.0
# 10    35           3            0.03               3.0
# 11    36           3            0.03               3.0
# 2     37           4            0.04               4.0
# 4     38           3            0.03               3.0
# 34    39           1            0.01               1.0
# 38    40           1            0.01               1.0
# 8     41           3            0.03               3.0
# 35    42           1            0.01               1.0
# 7     43           3            0.03               3.0
# 23    45           2            0.02               2.0
# 21    48           2            0.02               2.0
# 27    49           2            0.02               2.0
# 47    50           1            0.01               1.0
# 22    51           2            0.02               2.0
# 15    52           2            0.02               2.0
# 29    53           2            0.02               2.0
# 26    55           2            0.02               2.0
# 45    56           1            0.01               1.0
# 46    57           1            0.01               1.0
# 3     58           4            0.04               4.0
# 33    59           1            0.01               1.0
# 41    60           1            0.01               1.0
# 28    61           2            0.02               2.0
# 19    62           2            0.02               2.0
# 1     63           4            0.04               4.0
# 42    64           1            0.01               1.0
# 9     65           3            0.03               3.0
# 37    66           1            0.01               1.0
# 6     67           3            0.03               3.0
# 16    68           2            0.02               2.0
# 36    69           1            0.01               1.0
# 32    70           2            0.02               2.0

# %%
# Calcular la frecuencia acumulada
# Agregamos una nueva columna con el calculo
tabla_frecuencias["Frec. Acumulada"] = tabla_frecuencias["Frecuencia"].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativa  Frec. porcentual  Frec. Acumulada
# 13    18           2            0.02               2.0                2
# 24    19           2            0.02               2.0                4
# 39    20           1            0.01               1.0                5
# 14    21           2            0.02               2.0                7
# 0     22           6            0.06               6.0               13
# 18    23           2            0.02               2.0               15
# 30    24           2            0.02               2.0               17
# 17    25           2            0.02               2.0               19
# 43    26           1            0.01               1.0               20
# 25    28           2            0.02               2.0               22
# 20    29           2            0.02               2.0               24
# 40    30           1            0.01               1.0               25
# 12    31           3            0.03               3.0               28
# 31    32           2            0.02               2.0               30
# 5     33           3            0.03               3.0               33
# 44    34           1            0.01               1.0               34
# 10    35           3            0.03               3.0               37
# 11    36           3            0.03               3.0               40
# 2     37           4            0.04               4.0               44
# 4     38           3            0.03               3.0               47
# 34    39           1            0.01               1.0               48
# 38    40           1            0.01               1.0               49
# 8     41           3            0.03               3.0               52
# 35    42           1            0.01               1.0               53
# 7     43           3            0.03               3.0               56
# 23    45           2            0.02               2.0               58
# 21    48           2            0.02               2.0               60
# 27    49           2            0.02               2.0               62
# 47    50           1            0.01               1.0               63
# 22    51           2            0.02               2.0               65
# 15    52           2            0.02               2.0               67
# 29    53           2            0.02               2.0               69
# 26    55           2            0.02               2.0               71
# 45    56           1            0.01               1.0               72
# 46    57           1            0.01               1.0               73
# 3     58           4            0.04               4.0               77
# 33    59           1            0.01               1.0               78
# 41    60           1            0.01               1.0               79
# 28    61           2            0.02               2.0               81
# 19    62           2            0.02               2.0               83
# 1     63           4            0.04               4.0               87
# 42    64           1            0.01               1.0               88
# 9     65           3            0.03               3.0               91
# 37    66           1            0.01               1.0               92
# 6     67           3            0.03               3.0               95
# 16    68           2            0.02               2.0               97
# 36    69           1            0.01               1.0               98
# 32    70           2            0.02               2.0              100

# %% [markdown]
# ## Regla de sturges
# 1-. Es una regla que sirve para calcular el numero de clases o intervalos idóneo, en los que se debe de dividir un conjunto de datos c = 1 + Log₂ (N)

# %%
# Libreria de funciones matematicas
import math

# %%
print(edades)
# Out:
# [38, 24, 22, 48, 59, 24, 63, 31, 36, 53, 35, 33, 45, 22, 28, 33, 58, 22, 36, 45, 40, 32, 41, 58, 70, 20, 37, 64, 61, 49, 33, 55, 65, 49, 63, 43, 31, 22, 18, 57, 56, 65, 19, 51, 37, 34, 32, 37, 26, 67, 38, 29, 60, 62, 38, 18, 41, 29, 55, 67, 30, 23, 51, 39, 25, 68, 19, 63, 63, 61, 52, 68, 28, 52, 35, 66, 69, 22, 36, 23, 22, 67, 41, 21, 43, 21, 37, 42, 43, 62, 25, 70, 35, 65, 48, 58, 50, 53, 31, 58]

# %%
df_edades_sturges= pd. DataFrame({ "Edad": edades}) 
df_edades_sturges
# Out:
#     Edad
# 0     38
# 1     24
# 2     22
# 3     48
# 4     59
# ..   ...
# 95    58
# 96    50
# 97    53
# 98    31
# 99    58
#
# [100 rows x 1 columns]

# %%
# Calcular el numero de intervalos o clases utilizando la regla de sturges

n = len(edades)
k = int( 1 + math.log2(n))

print("Valor de n=", n, "\n Valor de k o numero de intervalos o clases =", k)
# Out:
# Valor de n= 100
#  Valor de k o numero de intervalos o clases = 7

# %%
tabla_frec_sturges = pd.cut( df_edades_sturges["Edad"], bins = k).value_counts().reset_index()
tabla_frec_sturges
# Out:
#               index  Edad
# 0  (17.948, 25.429]    19
# 1  (32.857, 40.286]    19
# 2    (62.571, 70.0]    17
# 3  (47.714, 55.143]    13
# 4  (55.143, 62.571]    12
# 5  (25.429, 32.857]    11
# 6  (40.286, 47.714]     9

# %%
tabla_frec_sturges.columns = ["Clase", "Frecuencia"]
tabla_frec_sturges
# Out:
#               Clase  Frecuencia
# 0  (17.948, 25.429]          19
# 1  (32.857, 40.286]          19
# 2    (62.571, 70.0]          17
# 3  (47.714, 55.143]          13
# 4  (55.143, 62.571]          12
# 5  (25.429, 32.857]          11
# 6  (40.286, 47.714]           9

# %%
# Ordenar la tabla de frecuecias por la clase o el intervalo
tabla_frec_sturges = tabla_frec_sturges.sort_values(by ="Clase")
tabla_frec_sturges
# Out:
#               Clase  Frecuencia
# 0  (17.948, 25.429]          19
# 5  (25.429, 32.857]          11
# 1  (32.857, 40.286]          19
# 6  (40.286, 47.714]           9
# 3  (47.714, 55.143]          13
# 4  (55.143, 62.571]          12
# 2    (62.571, 70.0]          17

# %%
tabla_frec_sturges["Frec. relativa"] = tabla_frec_sturges["Frecuencia"] / n
tabla_frec_sturges["Frec. porcentual"] = tabla_frec_sturges["Frecuencia"] / n * 100
tabla_frec_sturges["Frec. acumulada"] = tabla_frec_sturges["Frecuencia"].cumsum()

# %%
tabla_frec_sturges
# Out:
#               Clase  Frecuencia  Frec. relativa  Frec. porcentual  \
# 0  (17.948, 25.429]          19            0.19              19.0
# 5  (25.429, 32.857]          11            0.11              11.0
# 1  (32.857, 40.286]          19            0.19              19.0
# 6  (40.286, 47.714]           9            0.09               9.0
# 3  (47.714, 55.143]          13            0.13              13.0
# 4  (55.143, 62.571]          12            0.12              12.0
# 2    (62.571, 70.0]          17            0.17              17.0
#
#    Frec. acumulada
# 0               19
# 5               30
# 1               49
# 6               58
# 3               71
# 4               83
# 2              100

# %%
plt.hist(df_edades_sturges["Edad"], bins=k, alpha=0.5, rwidth=.95)
plt.title("Histograma de edades basado en la regla de Sturges")
plt.xlabel("Edades")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')
